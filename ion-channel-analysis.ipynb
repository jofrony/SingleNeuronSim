# %%
from ion_channel_analysis import ion_channel
from ion_channel_analysis import internal_parameters
from ion_channel_analysis import voltage_clamp
from ion_channel_analysis import save
from ion_channel_analysis import load
import numpy as np
import matplotlib.pyplot as plt

# %%
name_channel = 'na_ch'

# %%
ion_channel_current = dict()
voltage_interval = [-120,50]

IO = ion_channel.IonChannel(name=name_channel)
IO.set_up_soma()
soma_area = IO.return_area()
IO.voltage_clamp_interval(voltage_interval=voltage_interval,duration=10)
ion_channel_current.update({name_channel : np.array(IO.currents)})

# %%
plt.plot(ion_channel_current['na_ch'])
