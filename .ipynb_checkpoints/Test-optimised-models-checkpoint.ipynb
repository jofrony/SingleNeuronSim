# %%
# !echo $PATH | grep -q "$HOME/.local/bin" && echo .local/bin OK || echo .local/bin FAILED
# !which nrnivmodl >/dev/null && echo Neuron OK || echo Neuron FAILED
# !python3 -c 'import neuron' && echo PyNeuron OK || echo PyNeuron FAILED
# Out:
# .local/bin OK
# Neuron OK
# PyNeuron OK

# %%
from Neuron_model_extended import NeuronModel
import numpy as np
import json
import matplotlib.pyplot as plt
from modelSetUp import packageModel
from neuron import h
import bluepyopt.ephys as ephys

# %%
opt_dir = "/home/jofrony/Documents/Repositories/SingleNeuronModel/optimisation/single-cell/sbj4-170614_cell6/"

# %%
modelFile = "modelParameter.txt"
morphologyFile = opt_dir + "morphology/17JUL301751_170614_no6_MD_cell_1_x63-cor-rep-res5.swc"
parameterFile = "parameters.json"
mechanismsFile = "mechanisms.json"

# %%
# !rm -rf x86_64
# !nrnivmodl mechanisms
# Out:
# Creating x86_64 directory for .o files.
#
# /home/jofrony/Documents/Repositories/NEURON-test-suite
# ls: cannot access 'mechanisms/*.inc': No such file or directory
# mechanisms/bk_ch.mod mechanisms/bk_fs.mod mechanisms/bk_ms.mod mechanisms/ca_ch.mod mechanisms/cadyn_fs.mod mechanisms/cadyn_ms.mod mechanisms/cal12_ms.mod mechanisms/cal13_ms.mod mechanisms/cal_ch.mod mechanisms/caldyn_ms.mod mechanisms/can_fs.mod mechanisms/can_ms.mod mechanisms/cap_ch.mod mechanisms/caq_fs.mod mechanisms/caq_ms.mod mechanisms/car_fs.mod mechanisms/car_ms.mod mechanisms/cat32_ms.mod mechanisms/cat33_ms.mod mechanisms/concACh.mod mechanisms/concDAfile.mod mechanisms/concDA.mod mechanisms/hcn12_ch.mod mechanisms/hd_lts.mod mechanisms/im_lts.mod mechanisms/Im_ms.mod mechanisms/it_lts.mod mechanisms/kaf_fs.mod mechanisms/kaf_ms.mod mechanisms/kas_fs.mod mechanisms/kas_ms.mod mechanisms/kcnq_ch.mod mechanisms/kdrbca1_lts.mod mechanisms/kdr_fs.mod mechanisms/kdr_lts.mod mechanisms/kdr_ms.mod mechanisms/kir23_lts.mod mechanisms/kir2_ch.mod mechanisms/kir_fs.mod mechanisms/kir_ms.mod mechanisms/kv2_ch.mod mechanisms/kv4_ch.mod mechanisms/na2_ch.mod mechanisms/na3n_lts.mod mechanisms/na_ch.mod mechanisms/naf_fs.mod mechanisms/naf_lts.mod mechanisms/naf_ms.mod mechanisms/NO.mod mechanisms/par_ggap.mod mechanisms/sk_ch.mod mechanisms/sk_fs.mod mechanisms/sk_ms.mod mechanisms/tmgabaa.mod mechanisms/tmglut_M1RH_D1.mod mechanisms/tmglut.mod mechanisms/vecevent.mod
# bk_ch.mod bk_fs.mod bk_ms.mod ca_ch.mod cadyn_fs.mod cadyn_ms.mod cal12_ms.mod cal13_ms.mod cal_ch.mod caldyn_ms.mod can_fs.mod can_ms.mod cap_ch.mod caq_fs.mod caq_ms.mod car_fs.mod car_ms.mod cat32_ms.mod cat33_ms.mod concACh.mod concDAfile.mod concDA.mod hcn12_ch.mod hd_lts.mod im_lts.mod Im_ms.mod it_lts.mod kaf_fs.mod kaf_ms.mod kas_fs.mod kas_ms.mod kcnq_ch.mod kdrbca1_lts.mod kdr_fs.mod kdr_lts.mod kdr_ms.mod kir23_lts.mod kir2_ch.mod kir_fs.mod kir_ms.mod kv2_ch.mod kv4_ch.mod na2_ch.mod na3n_lts.mod na_ch.mod naf_fs.mod naf_lts.mod naf_ms.mod NO.mod par_ggap.mod sk_ch.mod sk_fs.mod sk_ms.mod tmgabaa.mod tmglut_M1RH_D1.mod tmglut.mod vecevent.mod
# "/usr/local/nrn/x86_64/bin/nocmodl" bk_ch
# "/usr/local/nrn/x86_64/bin/nocmodl" bk_fs
# "/usr/local/nrn/x86_64/bin/nocmodl" bk_ms
# "/usr/local/nrn/x86_64/bin/nocmodl" ca_ch
# Translating bk_ch.mod into bk_ch.c
# Translating bk_fs.mod into bk_fs.c
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "zinf", is not thread safe
# Translating ca_ch.mod into ca_ch.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk_ch.lo bk_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk_fs.lo bk_fs.c
# Notice: Assignment to the GLOBAL variable, "vol", is not thread safe
# Warning: Default 1 of PARAMETER diam will be ignored and set by NEURON.
# Translating bk_ms.mod into bk_ms.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o ca_ch.lo ca_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o bk_ms.lo bk_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk_ch.c  -fPIC -DPIC -o .libs/bk_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c ca_ch.c  -fPIC -DPIC -o .libs/ca_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk_fs.c  -fPIC -DPIC -o .libs/bk_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c bk_ms.c  -fPIC -DPIC -o .libs/bk_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cadyn_fs
# Translating cadyn_fs.mod into cadyn_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cadyn_fs.lo cadyn_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cadyn_ms
# Translating cadyn_ms.mod into cadyn_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cadyn_ms.lo cadyn_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cadyn_fs.c  -fPIC -DPIC -o .libs/cadyn_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cadyn_ms.c  -fPIC -DPIC -o .libs/cadyn_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cal12_ms
# Translating cal12_ms.mod into cal12_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal12_ms.lo cal12_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal12_ms.c  -fPIC -DPIC -o .libs/cal12_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cal13_ms
# Translating cal13_ms.mod into cal13_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal13_ms.lo cal13_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cal_ch
# Translating cal_ch.mod into cal_ch.c
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tau", is not thread safe
# Warning: Default 6.3 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cal_ch.lo cal_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" caldyn_ms
# Translating caldyn_ms.mod into caldyn_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caldyn_ms.lo caldyn_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal13_ms.c  -fPIC -DPIC -o .libs/cal13_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caldyn_ms.c  -fPIC -DPIC -o .libs/caldyn_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cal_ch.c  -fPIC -DPIC -o .libs/cal_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" can_fs
# Translating can_fs.mod into can_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o can_fs.lo can_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c can_fs.c  -fPIC -DPIC -o .libs/can_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" can_ms
# Translating can_ms.mod into can_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o can_ms.lo can_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" cap_ch
# Translating cap_ch.mod into cap_ch.c
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Warning: Default 35 of PARAMETER celsius will be ignored and set by NEURON.
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cap_ch.lo cap_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c can_ms.c  -fPIC -DPIC -o .libs/can_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" caq_fs
# Translating caq_fs.mod into caq_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caq_fs.lo caq_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cap_ch.c  -fPIC -DPIC -o .libs/cap_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caq_fs.c  -fPIC -DPIC -o .libs/caq_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" caq_ms
# Translating caq_ms.mod into caq_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o caq_ms.lo caq_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c caq_ms.c  -fPIC -DPIC -o .libs/caq_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" car_fs
# Translating car_fs.mod into car_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o car_fs.lo car_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" car_ms
# Translating car_ms.mod into car_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o car_ms.lo car_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c car_fs.c  -fPIC -DPIC -o .libs/car_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c car_ms.c  -fPIC -DPIC -o .libs/car_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cat32_ms
# Translating cat32_ms.mod into cat32_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cat32_ms.lo cat32_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cat32_ms.c  -fPIC -DPIC -o .libs/cat32_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" cat33_ms
# Translating cat33_ms.mod into cat33_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o cat33_ms.lo cat33_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c cat33_ms.c  -fPIC -DPIC -o .libs/cat33_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" concACh
# Translating concACh.mod into concACh.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concACh.lo concACh.c
# "/usr/local/nrn/x86_64/bin/nocmodl" concDAfile
# Translating concDAfile.mod into concDAfile.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concDAfile.lo concDAfile.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concACh.c  -fPIC -DPIC -o .libs/concACh.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concDAfile.c  -fPIC -DPIC -o .libs/concDAfile.o
# "/usr/local/nrn/x86_64/bin/nocmodl" concDA
# Translating concDA.mod into concDA.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o concDA.lo concDA.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c concDA.c  -fPIC -DPIC -o .libs/concDA.o
# "/usr/local/nrn/x86_64/bin/nocmodl" hcn12_ch
# Translating hcn12_ch.mod into hcn12_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o hcn12_ch.lo hcn12_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" hd_lts
# Translating hd_lts.mod into hd_lts.c
# Notice: Assignment to the GLOBAL variable, "linf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taul", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o hd_lts.lo hd_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" im_lts
# Translating im_lts.mod into im_lts.c
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o im_lts.lo im_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c hcn12_ch.c  -fPIC -DPIC -o .libs/hcn12_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c hd_lts.c  -fPIC -DPIC -o .libs/hd_lts.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c im_lts.c  -fPIC -DPIC -o .libs/im_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" Im_ms
# Translating Im_ms.mod into Im_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o Im_ms.lo Im_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c Im_ms.c  -fPIC -DPIC -o .libs/Im_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" it_lts
# Translating it_lts.mod into it_lts.c
# Warning: Default 36 of PARAMETER celsius will be ignored and set by NEURON.
# Warning: Default 2 of PARAMETER cao will be ignored and set by NEURON.
# Warning: Default 0.00024 of PARAMETER cai will be ignored and set by NEURON.
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o it_lts.lo it_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_fs
# Translating kaf_fs.mod into kaf_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_fs.lo kaf_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c it_lts.c  -fPIC -DPIC -o .libs/it_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kaf_ms
# Translating kaf_ms.mod into kaf_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kaf_ms.lo kaf_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_fs.c  -fPIC -DPIC -o .libs/kaf_fs.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kaf_ms.c  -fPIC -DPIC -o .libs/kaf_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kas_fs
# Translating kas_fs.mod into kas_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas_fs.lo kas_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas_fs.c  -fPIC -DPIC -o .libs/kas_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kas_ms
# Translating kas_ms.mod into kas_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kas_ms.lo kas_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kcnq_ch
# Translating kcnq_ch.mod into kcnq_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kcnq_ch.lo kcnq_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kas_ms.c  -fPIC -DPIC -o .libs/kas_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kcnq_ch.c  -fPIC -DPIC -o .libs/kcnq_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kdrbca1_lts
# Translating kdrbca1_lts.mod into kdrbca1_lts.c
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taun", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdrbca1_lts.lo kdrbca1_lts.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_fs
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdrbca1_lts.c  -fPIC -DPIC -o .libs/kdrbca1_lts.o
# Translating kdr_fs.mod into kdr_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_fs.lo kdr_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_fs.c  -fPIC -DPIC -o .libs/kdr_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_lts
# Translating kdr_lts.mod into kdr_lts.c
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taun", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_lts.lo kdr_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_lts.c  -fPIC -DPIC -o .libs/kdr_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kdr_ms
# Translating kdr_ms.mod into kdr_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kdr_ms.lo kdr_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kir23_lts
# Translating kir23_lts.mod into kir23_lts.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir23_lts.lo kir23_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kdr_ms.c  -fPIC -DPIC -o .libs/kdr_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir23_lts.c  -fPIC -DPIC -o .libs/kir23_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir2_ch
# Translating kir2_ch.mod into kir2_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir2_ch.lo kir2_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kir_fs
# Translating kir_fs.mod into kir_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir_fs.lo kir_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir2_ch.c  -fPIC -DPIC -o .libs/kir2_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir_fs.c  -fPIC -DPIC -o .libs/kir_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kir_ms
# Translating kir_ms.mod into kir_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kir_ms.lo kir_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" kv2_ch
# Translating kv2_ch.mod into kv2_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kv2_ch.lo kv2_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kir_ms.c  -fPIC -DPIC -o .libs/kir_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kv2_ch.c  -fPIC -DPIC -o .libs/kv2_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" kv4_ch
# Translating kv4_ch.mod into kv4_ch.c
# NEURON's CVode method ignores conservation
# Notice: Assignment to the GLOBAL variable, "alpha", is not thread safe
# Notice: Assignment to the GLOBAL variable, "beta", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o kv4_ch.lo kv4_ch.c
# "/usr/local/nrn/x86_64/bin/nocmodl" na2_ch
# Translating na2_ch.mod into na2_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na2_ch.lo na2_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c kv4_ch.c  -fPIC -DPIC -o .libs/kv4_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na3n_lts
# Translating na3n_lts.mod into na3n_lts.c
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "sinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taus", is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na3n_lts.lo na3n_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na2_ch.c  -fPIC -DPIC -o .libs/na2_ch.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na3n_lts.c  -fPIC -DPIC -o .libs/na3n_lts.o
# "/usr/local/nrn/x86_64/bin/nocmodl" na_ch
# Translating na_ch.mod into na_ch.c
# NEURON's CVode method ignores conservation
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o na_ch.lo na_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c na_ch.c  -fPIC -DPIC -o .libs/na_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_fs
# Translating naf_fs.mod into naf_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_fs.lo naf_fs.c
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_lts
# Translating naf_lts.mod into naf_lts.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_lts.lo naf_lts.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_fs.c  -fPIC -DPIC -o .libs/naf_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" naf_ms
# Translating naf_ms.mod into naf_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_lts.c  -fPIC -DPIC -o .libs/naf_lts.o
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o naf_ms.lo naf_ms.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c naf_ms.c  -fPIC -DPIC -o .libs/naf_ms.o
# "/usr/local/nrn/x86_64/bin/nocmodl" NO
# Translating NO.mod into NO.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o NO.lo NO.c
# "/usr/local/nrn/x86_64/bin/nocmodl" par_ggap
# Translating par_ggap.mod into par_ggap.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o par_ggap.lo par_ggap.c
# "/usr/local/nrn/x86_64/bin/nocmodl" sk_ch
# Translating sk_ch.mod into sk_ch.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk_ch.lo sk_ch.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c NO.c  -fPIC -DPIC -o .libs/NO.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c par_ggap.c  -fPIC -DPIC -o .libs/par_ggap.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk_ch.c  -fPIC -DPIC -o .libs/sk_ch.o
# "/usr/local/nrn/x86_64/bin/nocmodl" sk_fs
# Translating sk_fs.mod into sk_fs.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk_fs.lo sk_fs.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk_fs.c  -fPIC -DPIC -o .libs/sk_fs.o
# "/usr/local/nrn/x86_64/bin/nocmodl" sk_ms
# "/usr/local/nrn/x86_64/bin/nocmodl" tmgabaa
# Translating tmgabaa.mod into tmgabaa.c
# Notice: VERBATIM blocks are not thread safe
# Notice: scop_random is not thread safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmgabaa.lo tmgabaa.c
# Translating sk_ms.mod into sk_ms.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o sk_ms.lo sk_ms.c
# "/usr/local/nrn/x86_64/bin/nocmodl" tmglut_M1RH_D1
# Translating tmglut_M1RH_D1.mod into tmglut_M1RH_D1.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmglut_M1RH_D1.lo tmglut_M1RH_D1.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c sk_ms.c  -fPIC -DPIC -o .libs/sk_ms.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmgabaa.c  -fPIC -DPIC -o .libs/tmgabaa.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmglut_M1RH_D1.c  -fPIC -DPIC -o .libs/tmglut_M1RH_D1.o
# "/usr/local/nrn/x86_64/bin/nocmodl" tmglut
# Translating tmglut.mod into tmglut.c
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o tmglut.lo tmglut.c
# "/usr/local/nrn/x86_64/bin/nocmodl" vecevent
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c tmglut.c  -fPIC -DPIC -o .libs/tmglut.o
# Translating vecevent.mod into vecevent.c
# Notice: ARTIFICIAL_CELL is a synonym for POINT_PROCESS which hints that it
# only affects and is affected by discrete events. As such it is not
# located in a section and is not associated with an integrator
# Thread Safe
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o vecevent.lo vecevent.c
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=compile mpicc -DHAVE_CONFIG_H  -I. -I.. -I"/usr/local/nrn/include/nrn" -I"/usr/local/nrn/x86_64/lib"      -g -O2 -c -o mod_func.lo mod_func.c
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c vecevent.c  -fPIC -DPIC -o .libs/vecevent.o
# libtool: compile:  mpicc -DHAVE_CONFIG_H -I. -I.. -I/usr/local/nrn/include/nrn -I/usr/local/nrn/x86_64/lib -g -O2 -c mod_func.c  -fPIC -DPIC -o .libs/mod_func.o
# "/usr/local/nrn/share/nrn/libtool" --tag=CC --mode=link mpicc -module  -g -O2    -o libnrnmech.la -rpath "/usr/local/nrn/x86_64/lib"  bk_ch.lo bk_fs.lo bk_ms.lo ca_ch.lo cadyn_fs.lo cadyn_ms.lo cal12_ms.lo cal13_ms.lo cal_ch.lo caldyn_ms.lo can_fs.lo can_ms.lo cap_ch.lo caq_fs.lo caq_ms.lo car_fs.lo car_ms.lo cat32_ms.lo cat33_ms.lo concACh.lo concDAfile.lo concDA.lo hcn12_ch.lo hd_lts.lo im_lts.lo Im_ms.lo it_lts.lo kaf_fs.lo kaf_ms.lo kas_fs.lo kas_ms.lo kcnq_ch.lo kdrbca1_lts.lo kdr_fs.lo kdr_lts.lo kdr_ms.lo kir23_lts.lo kir2_ch.lo kir_fs.lo kir_ms.lo kv2_ch.lo kv4_ch.lo na2_ch.lo na3n_lts.lo na_ch.lo naf_fs.lo naf_lts.lo naf_ms.lo NO.lo par_ggap.lo sk_ch.lo sk_fs.lo sk_ms.lo tmgabaa.lo tmglut_M1RH_D1.lo tmglut.lo vecevent.lo mod_func.lo  -L"/usr/local/nrn/x86_64/lib" -lnrnoc -loc -lmemacs -lnrnmpi -lscopmath -lsparse13 -lreadline -lncurses -ltinfo -L"/usr/local/nrn/x86_64/lib" -lnrniv -livoc -lneuron_gnu -lmeschach -lsundials       -lm -ldl
# libtool: link: mpicc -shared  -fPIC -DPIC  .libs/bk_ch.o .libs/bk_fs.o .libs/bk_ms.o .libs/ca_ch.o .libs/cadyn_fs.o .libs/cadyn_ms.o .libs/cal12_ms.o .libs/cal13_ms.o .libs/cal_ch.o .libs/caldyn_ms.o .libs/can_fs.o .libs/can_ms.o .libs/cap_ch.o .libs/caq_fs.o .libs/caq_ms.o .libs/car_fs.o .libs/car_ms.o .libs/cat32_ms.o .libs/cat33_ms.o .libs/concACh.o .libs/concDAfile.o .libs/concDA.o .libs/hcn12_ch.o .libs/hd_lts.o .libs/im_lts.o .libs/Im_ms.o .libs/it_lts.o .libs/kaf_fs.o .libs/kaf_ms.o .libs/kas_fs.o .libs/kas_ms.o .libs/kcnq_ch.o .libs/kdrbca1_lts.o .libs/kdr_fs.o .libs/kdr_lts.o .libs/kdr_ms.o .libs/kir23_lts.o .libs/kir2_ch.o .libs/kir_fs.o .libs/kir_ms.o .libs/kv2_ch.o .libs/kv4_ch.o .libs/na2_ch.o .libs/na3n_lts.o .libs/na_ch.o .libs/naf_fs.o .libs/naf_lts.o .libs/naf_ms.o .libs/NO.o .libs/par_ggap.o .libs/sk_ch.o .libs/sk_fs.o .libs/sk_ms.o .libs/tmgabaa.o .libs/tmglut_M1RH_D1.o .libs/tmglut.o .libs/vecevent.o .libs/mod_func.o   -Wl,-rpath -Wl,/usr/local/nrn/x86_64/lib -Wl,-rpath -Wl,/usr/local/nrn/x86_64/lib -L/usr/local/nrn/x86_64/lib /usr/local/nrn/x86_64/lib/libnrnoc.so /usr/local/nrn/x86_64/lib/liboc.so -lX11 /usr/local/nrn/x86_64/lib/libmemacs.so /usr/local/nrn/x86_64/lib/libnrnmpi.so /usr/local/nrn/x86_64/lib/libscopmath.so /usr/local/nrn/x86_64/lib/libsparse13.so /usr/local/nrn/x86_64/lib/libreadline.so -lncurses -ltinfo /usr/local/nrn/x86_64/lib/libnrniv.so /usr/local/nrn/x86_64/lib/libivoc.so /usr/local/nrn/x86_64/lib/libneuron_gnu.so /usr/local/nrn/x86_64/lib/libmeschach.so /usr/local/nrn/x86_64/lib/libsundials.so -lm -ldl  -g -O2   -Wl,-soname -Wl,libnrnmech.so.0 -o .libs/libnrnmech.so.0.0.0
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so.0" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so.0")
# libtool: link: (cd ".libs" && rm -f "libnrnmech.so" && ln -s "libnrnmech.so.0.0.0" "libnrnmech.so")
# libtool: link: ( cd ".libs" && rm -f "libnrnmech.la" && ln -s "../libnrnmech.la" "libnrnmech.la" )
# Successfully created x86_64/special

# %%
packageModel(modelFile) # Packaging the manual tuning file modelParameter.txt into the two files for NeuroModel: parameters.json and mechanisms.json

infoCell = dict()

modelCell=NeuronModel(param_file=parameterFile,morph_file=morphologyFile,mech_file=mechanismsFile,cell_name="TEST")



simulator=ephys.simulators.NrnSimulator(cvode_active=False) # In here is neuron.h., simulator.neuron.h = neuron.h. in common NEURON+python syntax

modelCell.instantiate(sim=simulator)  

infoCell.update({"Cell": modelCell})

infoCell.update({"simulator": simulator})

infoCell.update({"synapses":list()})
    
vSave = simulator.neuron.h.Vector()

for isec, sec in enumerate(modelCell.icell.soma):

	 for seg in sec:
                  
                  vSave.record(getattr(seg,'_ref_v'))
                  infoCell.update({"soma_access":seg})
               
                  spikeTime = simulator.neuron.h.Vector()
                  recordingSpikingActivity = simulator.neuron.h.NetCon(getattr(seg,'_ref_v'),None, sec = sec)
                  recordingSpikingActivity.threshold = 0
                  recordingSpikingActivity.record(spikeTime)
                                         
                  infoCell.update({"spike_con": recordingSpikingActivity})
                  infoCell.update({"spike_train": spikeTime})

                  infoCell.update({"soma_voltage":vSave})
 


for sec in simulator.neuron.h.allsec():
    
    for seg in sec:
             '''
             Here we are iterating through the whole morphology, which is divided into compartments (sec) and compartments are made up of segments (seg).
             We can place current clamp, voltage clamp and receptors on the segments to stimulate the neuron

             For optimisation of the neuron we use current clamps in the soma and stimulate with protocols consisting of step currents __|¨¨|__ 
             with a holding current in pA and a stimulation current in pA. E.g. -300 pA during whole protocol (3000 ms)  and 100pA (1000 ms)

             
             '''
           
            
             if "soma" in sec.name():
                      '''
                      If you want to place point processes on the soma. You can place it here

                      '''
                      IClampHolding = simulator.neuron.h.IClamp(seg)
                      IClampHolding.delay = 0
                      IClampHolding.dur = 2000
                      IClampHolding.amp = -0.4257 # nA, but experiments usually use pA

                      IClampStimulation = simulator.neuron.h.IClamp(seg)
                      IClampStimulation.delay = 100
                      IClampStimulation.dur = 1000
                      IClampStimulation.amp = 0.4 # nA, but experiments usually use pA
                  
                      
             elif "dend" in sec.name():

                      '''
                      If you want to place point processes on the dendrite. You can place it here.

                      By using print(dir(seg)) you can see what is availble to do on the current seg
                      
                      For example this is the output I got:

                      'area', 'ca_ch', 'ca_ion', 'cm', 'diam', 'k_ion', 'kir2_ch', 'na2_ch', 'na_ion', 'node_index', 'pas', 'point_processes', 'ri', 'sec', 'v', 'volume', 'x'
                      If you for example add print(seg.point_processes()) to the code, you can see what point processes you have placed here.

                      You can try to add synapses only on distal dendrites, you can get information on the x,y,z. Soma is not at origo, need to correct for this!
                      sec.x3d(i),
                      sec.y3d(i),
                      sec.z3d(i),


                      '''
                  
                      expSynapse=simulator.neuron.h.Exp2Syn(seg)
                      expSynapse.tau1=2 # You can change the parameter of the synapse - we have models for this for AMPA and NMDA receptor and GABA_A receptors, but this is a simpler model
                      expSynapse.tau2=10 # you can also change syn.e, which is the reversal time
                      
                      ExtrinsicSpikeTimes = [500,600,700,800]  # The stimulation times only have to be part of a list (in ms)
                      VecStim = simulator.neuron.h.VecStim()
                      convertedVector = simulator.neuron.h.Vector(ExtrinsicSpikeTimes)
                      VecStim.play(convertedVector)
                      
                      ncToSynapse = simulator.neuron.h.NetCon(VecStim,expSynapse)
                      ncToSynapse.delay=1
                      ncToSynapse.threshold=0
                      #ncToSynapse.weight[0]=0.1 # You can determine the weight

                      '''
                      dendriteResponse = simulator.neuron.h.Vector()
                      dendriteResponse.record(getattr(seg,'_ref_v'))
                      infoCell["synapses"].append(dendriteResponse)
                      '''
                      
tSave = simulator.neuron.h.Vector()
tSave.record(simulator.neuron.h._ref_t)

simulator.neuron.h.tstop=1500
simulator.neuron.h.run()


cellVoltage=infoCell["soma_voltage"]    
plt.figure(0)
plt.plot(tSave,cellVoltage,label="membrane potential",c='black')
plt.xlabel("Time (ms)")
plt.ylabel("Membrane potential (mV)")
plt.title("TestCell Simulation")

for dendriteLocation in infoCell["synapses"]:
         plt.figure(1)
         plt.plot(tSave,dendriteLocation)

plt.show()
